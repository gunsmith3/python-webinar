# %%
import os

# %%
prod_file = os.path.join('data','03_Prod.mdout')
print(Prod_file)
# Out:
# data\03_Prod.mdout

# %%
outfile = open(prod_file,'r')

# %%
outfile.close()

# %%
with open(prod_file,'r') as outfile:
    data = outfile.readlines()

# %%
for line in data:
    if 'Etot' in line:
        energy_line = line
        word = energy_line.split()
        word = word[2]
        print(word)
# Out:
# -4585.1049
# -4573.5326
# -4548.1223
# -4525.3410
# -4542.8995
# -4550.9376
# -4543.8652
# -4570.4109
# -4550.4225
# -4585.2078
# -4577.3788
# -4583.5594
# -4605.5086
# -4615.4200
# -4583.6069
# -4534.2492
# -4571.4911
# -4580.2937
# -4555.4327
# -4567.5687
# -4566.0038
# -4547.9737
# -4603.6717
# -4611.0889
# -4694.2189
# -4678.6558
# -4679.2889
# -4650.4214
# -4637.4849
# -4677.2461
# -4659.6974
# -4592.8300
# -4622.1237
# -4626.0868
# -4614.5996
# -4625.5348
# -4569.7752
# -4625.0792
# -4653.4614
# -4637.6852
# -4643.8673
# -4619.5255
# -4663.3843
# -4631.8386
# -4680.3524
# -4722.1579
# -4696.5022
# -4729.6126
# -4703.1835
# -4707.8668
# -4660.0768
# -4673.0967
# -4656.3795
# -4627.9210
# -4599.7806
# -4648.8831
# -4649.4773
# -4665.3345
# -4693.9727
# -4726.4832
# -4744.9909
# -4788.9469
# -4724.8673
# -4724.9143
# -4685.3320
# -4721.0018
# -4755.1232
# -4810.7441
# -4796.7949
# -4737.2496
# -4735.1629
# -4733.8855
# -4781.2227
# -4789.1473
# -4813.7562
# -4817.4775
# ...

# %%
for line in data:
    if 'Etot' in line:
        energy_line = line
        word = energy_line.split()
        word = word[2]
    if 'TIME(PS)' in line:
        time_line = line
        word1 = time_line.split()
        word1 = word1[5]
        print('Time:',word1,' ','Etot:',word)
# Out:
# Time: 20.200   Etot: 120.4662
# Time: 20.400   Etot: -4585.1049
# Time: 20.600   Etot: -4573.5326
# Time: 20.800   Etot: -4548.1223
# Time: 21.000   Etot: -4525.3410
# Time: 21.200   Etot: -4542.8995
# Time: 21.400   Etot: -4550.9376
# Time: 21.600   Etot: -4543.8652
# Time: 21.800   Etot: -4570.4109
# Time: 22.000   Etot: -4550.4225
# Time: 22.200   Etot: -4585.2078
# Time: 22.400   Etot: -4577.3788
# Time: 22.600   Etot: -4583.5594
# Time: 22.800   Etot: -4605.5086
# Time: 23.000   Etot: -4615.4200
# Time: 23.200   Etot: -4583.6069
# Time: 23.400   Etot: -4534.2492
# Time: 23.600   Etot: -4571.4911
# Time: 23.800   Etot: -4580.2937
# Time: 24.000   Etot: -4555.4327
# Time: 24.200   Etot: -4567.5687
# Time: 24.400   Etot: -4566.0038
# Time: 24.600   Etot: -4547.9737
# Time: 24.800   Etot: -4603.6717
# Time: 25.000   Etot: -4611.0889
# Time: 25.200   Etot: -4694.2189
# Time: 25.400   Etot: -4678.6558
# Time: 25.600   Etot: -4679.2889
# Time: 25.800   Etot: -4650.4214
# ...
