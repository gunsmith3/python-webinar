# %% [markdown]
# # Pandas Lesson
#
# How to process data using Pandas

# %%
import pandas as pd

# %%
periodic_data = pd.read_csv('PubChemElements_all.csv')

# %%
# See the first 5 rows
periodic_data.head()
# Out:
#    AtomicNumber Symbol       Name  AtomicMass CPKHexColor  \
# 0             1      H   Hydrogen    1.008000      FFFFFF
# 1             2     He     Helium    4.002600      D9FFFF
# 2             3     Li    Lithium    7.000000      CC80FF
# 3             4     Be  Beryllium    9.012183      C2FF00
# 4             5      B      Boron   10.810000      FFB5B5
#
#   ElectronConfiguration  Electronegativity  AtomicRadius  IonizationEnergy  \
# 0                   1s1               2.20         120.0            13.598
# 1                   1s2                NaN         140.0            24.587
# 2               [He]2s1               0.98         182.0             5.392
# 3               [He]2s2               1.57         153.0             9.323
# 4           [He]2s2 2p1               2.04         192.0             8.298
#
#    ElectronAffinity OxidationStates StandardState  MeltingPoint  BoilingPoint  \
# 0             0.754          +1, -1           Gas         13.81         20.28
# ...

# %%
# See the last 5 rows
periodic_data.tail()
# Out:
#      AtomicNumber Symbol         Name  AtomicMass CPKHexColor  \
# 113           114     Fl    Flerovium     289.191         NaN
# 114           115     Mc    Moscovium     290.196         NaN
# 115           116     Lv  Livermorium     293.205         NaN
# 116           117     Ts   Tennessine     294.211         NaN
# 117           118     Og    Oganesson     294.214         NaN
#
#                  ElectronConfiguration  Electronegativity  AtomicRadius  \
# 113  [Rn]7s2 7p2 5f14 6d10 (predicted)                NaN           NaN
# 114  [Rn]7s2 7p3 5f14 6d10 (predicted)                NaN           NaN
# 115  [Rn]7s2 7p4 5f14 6d10 (predicted)                NaN           NaN
# 116  [Rn]7s2 7p5 5f14 6d10 (predicted)                NaN           NaN
# 117  [Rn]7s2 7p6 5f14 6d10 (predicted)                NaN           NaN
#
#      IonizationEnergy  ElectronAffinity        OxidationStates  \
# 113               NaN               NaN           6, 4,2, 1, 0
# ...

# %%
# Get statistic for columns with numbers
periodic_data.describe()
# Out:
#        AtomicNumber  AtomicMass  Electronegativity  AtomicRadius  \
# count    118.000000  118.000000          95.000000     99.000000
# mean      59.500000  146.607635           1.732316    209.464646
# std       34.207699   89.845304           0.635187     38.569130
# min        1.000000    1.008000           0.700000    120.000000
# 25%       30.250000   66.480000           1.290000    187.000000
# 50%       59.500000  142.573850           1.620000    209.000000
# 75%       88.750000  226.777165           2.170000    232.000000
# max      118.000000  294.214000           3.980000    348.000000
#
#        IonizationEnergy  ElectronAffinity  MeltingPoint  BoilingPoint  \
# count        102.000000         57.000000    103.000000     93.000000
# mean           7.997255          1.072140   1273.740553   2536.212473
# std            3.339066          0.879163    888.853859   1588.410919
# min            3.894000          0.079000      0.950000      4.220000
# ...

# %%
periodic_data.iloc[35:45]
# Out:
#     AtomicNumber Symbol        Name  AtomicMass CPKHexColor  \
# 35            36     Kr     Krypton    83.80000      5CB8D1
# 36            37     Rb    Rubidium    85.46800      702EB0
# 37            38     Sr   Strontium    87.60000      00FF00
# 38            39      Y     Yttrium    88.90580      94FFFF
# 39            40     Zr   Zirconium    91.22000      94E0E0
# 40            41     Nb     Niobium    92.90640      73C2C9
# 41            42     Mo  Molybdenum    96.00000      54B5B5
# 42            43     Tc  Technetium    97.90721      3B9E9E
# 43            44     Ru   Ruthenium   101.10000      248F8F
# 44            45     Rh     Rhodium   102.90550      0A7D8C
#
#    ElectronConfiguration  Electronegativity  AtomicRadius  IonizationEnergy  \
# 35      [Ar]4s2 3d10 4p6               3.00         202.0            14.000
# 36               [Kr]5s1               0.82         303.0             4.177
# ...

# %%
periodic_data.iloc[35:45,:4]
# Out:
#     AtomicNumber Symbol        Name  AtomicMass
# 35            36     Kr     Krypton    83.80000
# 36            37     Rb    Rubidium    85.46800
# 37            38     Sr   Strontium    87.60000
# 38            39      Y     Yttrium    88.90580
# 39            40     Zr   Zirconium    91.22000
# 40            41     Nb     Niobium    92.90640
# 41            42     Mo  Molybdenum    96.00000
# 42            43     Tc  Technetium    97.90721
# 43            44     Ru   Ruthenium   101.10000
# 44            45     Rh     Rhodium   102.90550

# %%
periodic_data.iloc[0]
# Out:
# AtomicNumber                     1
# Symbol                           H
# Name                      Hydrogen
# AtomicMass                   1.008
# CPKHexColor                 FFFFFF
# ElectronConfiguration          1s1
# Electronegativity              2.2
# AtomicRadius                   120
# IonizationEnergy            13.598
# ElectronAffinity             0.754
# OxidationStates             +1, -1
# StandardState                  Gas
# MeltingPoint                 13.81
# BoilingPoint                 20.28
# Density                  8.988e-05
# GroupBlock                Nonmetal
# YearDiscovered                1766
# Name: 0, dtype: object

# %%
# Use the iloc function to 
# select row 5
# select Row 30 to the end and the first 4 column

# %%
periodic_data.iloc[5]
# Out:
# AtomicNumber                       6
# Symbol                             C
# Name                          Carbon
# AtomicMass                    12.011
# CPKHexColor                   909090
# ElectronConfiguration    [He]2s2 2p2
# Electronegativity               2.55
# AtomicRadius                     170
# IonizationEnergy               11.26
# ElectronAffinity               1.263
# OxidationStates           +4, +2, -4
# StandardState                  Solid
# MeltingPoint                    3823
# BoilingPoint                    4098
# Density                        2.267
# GroupBlock                  Nonmetal
# YearDiscovered               Ancient
# Name: 5, dtype: object

# %%
periodic_data.iloc[30:,:4]
# Out:
#      AtomicNumber Symbol           Name  AtomicMass
# 30             31     Ga        Gallium   69.720000
# 31             32     Ge      Germanium   72.630000
# 32             33     As        Arsenic   74.921590
# 33             34     Se       Selenium   78.970000
# 34             35     Br        Bromine   79.900000
# 35             36     Kr        Krypton   83.800000
# 36             37     Rb       Rubidium   85.468000
# 37             38     Sr      Strontium   87.600000
# 38             39      Y        Yttrium   88.905800
# 39             40     Zr      Zirconium   91.220000
# 40             41     Nb        Niobium   92.906400
# 41             42     Mo     Molybdenum   96.000000
# 42             43     Tc     Technetium   97.907210
# 43             44     Ru      Ruthenium  101.100000
# 44             45     Rh        Rhodium  102.905500
# 45             46     Pd      Palladium  106.400000
# 46             47     Ag         Silver  107.868000
# ...

# %%
# Use loc to access information by name
periodic_data.loc[:,["Symbol","AtomicMass"]]
# Out:
#     Symbol  AtomicMass
# 0        H    1.008000
# 1       He    4.002600
# 2       Li    7.000000
# 3       Be    9.012183
# 4        B   10.810000
# 5        C   12.011000
# 6        N   14.007000
# 7        O   15.999000
# 8        F   18.998403
# 9       Ne   20.180000
# 10      Na   22.989769
# 11      Mg   24.305000
# 12      Al   26.981538
# 13      Si   28.085000
# 14       P   30.973762
# 15       S   32.070000
# 16      Cl   35.450000
# 17      Ar   39.900000
# 18       K   39.098000
# 19      Ca   40.080000
# 20      Sc   44.955910
# 21      Ti   47.870000
# 22       V   50.941000
# 23      Cr   51.996000
# 24      Mn   54.938040
# 25      Fe   55.840000
# 26      Co   58.933190
# 27      Ni   58.693000
# 28      Cu   63.550000
# 29      Zn   65.400000
# ..     ...         ...
# 88      Ac  227.027750
# 89      Th  232.038000
# 90      Pa  231.035900
# 91       U  238.028900
# 92      Np  237.048170
# 93      Pu  244.064200
# 94      Am  243.061380
# 95      Cm  247.070350
# ...

# %%
# Get column of data by name.
# periodic_data["column_name"]

# %%
periodic_data["BoilingPointC"] = periodic_data["BoilingPoint"] - 273.15

# %%
periodic_data.head()
# Out:
#    AtomicNumber Symbol       Name  AtomicMass CPKHexColor  \
# 0             1      H   Hydrogen    1.008000      FFFFFF
# 1             2     He     Helium    4.002600      D9FFFF
# 2             3     Li    Lithium    7.000000      CC80FF
# 3             4     Be  Beryllium    9.012183      C2FF00
# 4             5      B      Boron   10.810000      FFB5B5
#
#   ElectronConfiguration  Electronegativity  AtomicRadius  IonizationEnergy  \
# 0                   1s1               2.20         120.0            13.598
# 1                   1s2                NaN         140.0            24.587
# 2               [He]2s1               0.98         182.0             5.392
# 3               [He]2s2               1.57         153.0             9.323
# 4           [He]2s2 2p1               2.04         192.0             8.298
#
#    ElectronAffinity OxidationStates StandardState  MeltingPoint  BoilingPoint  \
# 0             0.754          +1, -1           Gas         13.81         20.28
# ...

# %%
periodic_data.to_csv('periodic_table_new.csv')
